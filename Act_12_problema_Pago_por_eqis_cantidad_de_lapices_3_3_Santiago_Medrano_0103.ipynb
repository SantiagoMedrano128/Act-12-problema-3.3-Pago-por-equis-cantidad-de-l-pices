# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoMedrano128/Act-12-problema-3.3-Pago-por-equis-cantidad-de-l-pices/blob/main/Act_12_problema_Pago_por_eqis_cantidad_de_lapices_3_3_Santiago_Medrano_0103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Santiago Medrano NL = 37 Fecha 26/Mar/2026
# ### Calculando cantidad a pagar por lapices usando if else
# ### Mirar diagrama de flujo
# <img src="https://raw.githubusercontent.com/SantiagoMedrano128/Act-12-problema-3.3-Pago-por-equis-cantidad-de-l-pices/refs/heads/main/pago%20por%20lapices.jpg" alt="Imagen aleatoria" width="350" height="300">
#
# ## Las variables
# 1. X --> Cantidad de lapices
# 2. PAG --> Pago que se realizara por los lapices
#
# ## Formulas
# * $PAG = X * 0.85$
# * $PAG = X * 0.85$
#
# ## Diagrama de flujo LucidChart
# <img src="https://raw.githubusercontent.com/SantiagoMedrano128/Act-12-problema-3.3-Pago-por-equis-cantidad-de-l-pices/refs/heads/main/DF%20if%20else%20pago%202.png
# " alt="Imagen aleatoria" width="350" height="500">

# %%
# Para cuando es verdadero (si)
# Calcular el pago usando if else
# Dato de entrada X
# Mostrar el pago segun la decision

X = int(input("Ingrese la cantidad de lapices: "))
if X < 1000 :
 PAG = X * 0.95
else:
  PAG = X * 0.85
print("El pago a realizar es: ", PAG)
print("Fin del programa")
print("Programa Realizado por Santiago Medrano NL = 37")
# Out:
# Ingrese la cantidad de lapices: 1500
# El pago a realizar es:  1275.0
# Fin del programa
# Programa Realizado por Santiago Medrano NL = 37

# %%
# Para cuando es falso (NO)
# Calcular el pago usando if else
# Dato de entrada X
# Mostrar el pago segun la decision

X = int(input("Ingrese la cantidad de lapices: "))
if X < 1000 :
 PAG = X * 0.95
else:
  PAG = X * 0.85
print("El pago a realizar es: ", PAG)
print("Fin del programa")
print("Programa Realizado por Santiago Medrano NL = 37")
# Out:
# Ingrese la cantidad de lapices: 950
# El pago a realizar es:  902.5
# Fin del programa
# Programa Realizado por Santiago Medrano NL = 37

# %% [markdown]
# ## Relacion entre codigo y diagrama de flujo
# <img src="https://raw.githubusercontent.com/SantiagoMedrano128/Act-12-problema-3.3-Pago-por-equis-cantidad-de-l-pices/refs/heads/main/TLDraw%20codigo%20DF%20(2).png
# " alt="Imagen aleatoria" width="900" height="500">
